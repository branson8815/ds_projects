# %%
#!/usr/bin/env python3
# test for initial commit on this file
import pandas as pd
import numpy as np
import os as os
from kaggle.api.kaggle_api_extended import KaggleApi
import matplotlib.pyplot as plt

# %%
# Initialize the Kaggle API client
api = KaggleApi()
api.authenticate()  # This will use your credentials from the KAGGLE_CONFIG_DIR

dataset_name = "nelgiriyewithana/top-spotify-songs-2023"
api.dataset_download_files(
    dataset_name,
    path="/Users/kerouac/Desktop/project_work/programming_projects",
    unzip=True,
)

sample_dataset = pd.read_csv(
    "/Users/kerouac/Desktop/project_work/programming_projects/spotify-2023.csv",
    encoding="latin1",
)

print(sample_dataset)
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                  147  141381703                  43  ...  125   B  Major
# 1                   48  133716286                  48  ...   92  C#  Major
# 2                  113  140003974                  94  ...  138   F  Major
# 3                  100  800840817                 116  ...  170   A  Major
# 4                   50  303236322                  84  ...  144   A  Minor
# ..                 ...        ...                 ...  ...  ...  ..    ...
# 948                  0   91473363                  61  ...  144   A  Major
# 949                  0  121871870                   4  ...  166  F#  Major
# 950                  0   73513683                   2  ...   92  C#  Major
# 951                  0  133895612                  29  ...   97  C#  Major
# 952                  2   96007391                  27  ...   90   E  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0               80         89       83             31                   0
# 1               71         61       74              7                   0
# 2               51         32       53             17                   0
# 3               55         58       72             11                   0
# 4               65         23       80             14                  63
# ..             ...        ...      ...            ...                 ...
# 948             60         24       39             57                   0
# 949             42          7       24             83                   1
# 950             80         81       67              4                   0
# 951             82         67       77              8                   0
# 952             61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [953 rows x 24 columns]

# %%
one_entry = sample_dataset.iloc[10,10]

# %%
one_entry
# Out:
# 205

# %%
sample_dataset
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 0             2023               7            14                   553
# 1             2023               3            23                  1474
# 2             2023               6            30                  1397
# 3             2019               8            23                  7858
# 4             2023               5            18                  3133
# ..             ...             ...           ...                   ...
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                  147  141381703                  43  ...  125   B  Major
# 1                   48  133716286                  48  ...   92  C#  Major
# 2                  113  140003974                  94  ...  138   F  Major
# 3                  100  800840817                 116  ...  170   A  Major
# 4                   50  303236322                  84  ...  144   A  Minor
# ..                 ...        ...                 ...  ...  ...  ..    ...
# 948                  0   91473363                  61  ...  144   A  Major
# 949                  0  121871870                   4  ...  166  F#  Major
# 950                  0   73513683                   2  ...   92  C#  Major
# 951                  0  133895612                  29  ...   97  C#  Major
# 952                  2   96007391                  27  ...   90   E  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0               80         89       83             31                   0
# 1               71         61       74              7                   0
# 2               51         32       53             17                   0
# 3               55         58       72             11                   0
# 4               65         23       80             14                  63
# ..             ...        ...      ...            ...                 ...
# 948             60         24       39             57                   0
# 949             42          7       24             83                   1
# 950             80         81       67              4                   0
# 951             82         67       77              8                   0
# 952             61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 0             8              4
# 1            10              4
# 2            31              6
# 3            11             15
# 4            11              6
# ..          ...            ...
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [953 rows x 24 columns]

# %%
bad_bunny_songs = sample_dataset[sample_dataset.iloc[:,1] == 'Bad Bunny']

# %%
bad_bunny_songs
# Out:
#                track_name artist(s)_name  artist_count  released_year  \
# 4          WHERE SHE GOES      Bad Bunny             1           2023
# 192     Titi Me Preguntï¿      Bad Bunny             1           2022
# 239                Efecto      Bad Bunny             1           2022
# 362              Neverita      Bad Bunny             1           2022
# 377           Moscow Mule      Bad Bunny             1           2022
# 422              Yonaguni      Bad Bunny             1           2021
# 676           A Tu Merced      Bad Bunny             1           2020
# 716               La Zona      Bad Bunny             1           2020
# 766  Despuï¿½ï¿½s de la P      Bad Bunny             1           2022
# 767             Un Ratito      Bad Bunny             1           2022
# 770      Yo No Soy Celoso      Bad Bunny             1           2022
# 773  Me Fui de Vacaciones      Bad Bunny             1           2022
# 778            Dos Mil 16      Bad Bunny             1           2022
# 781               Un Coco      Bad Bunny             1           2022
# 784              Aguacero      Bad Bunny             1           2022
# 786      Un Verano Sin Ti      Bad Bunny             1           2022
# 788   Ensï¿½ï¿½ï¿½ï¿½ame       Bad Bunny             1           2022
# 789            El Apagï¿½      Bad Bunny             1           2022
# 792                Agosto      Bad Bunny             1           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 4                 5            18                  3133                 50
# 192               5             6                  9037                 42
# 239               5             6                  4004                 33
# 362               5             6                  2590                 30
# 377               5             6                  4572                 33
# 422               6             4                  9644                 28
# 676               2            29                  4214                 11
# 716               2            29                  1188                  0
# 766               5             6                  2229                  0
# 767               5             6                  1112                  6
# 770               5             6                  1179                  0
# 773               5             6                  1443                  0
# 778               5             6                   892                  3
# 781               5             6                  1029                 28
# 784               5             6                   829                  0
# 786               5             6                  1004                  1
# 788               5             6                  1112                  3
# 789               5             6                  1209                  0
# 792               5             6                   897                  0
#
#         streams  in_apple_playlists  ...  bpm  key   mode danceability_%  \
# 4     303236322                  84  ...  144    A  Minor             65
# 192  1264310836                 124  ...  107    F  Minor             65
# 239  1047480053                  34  ...   98    G  Minor             80
# 362   671365962                  20  ...  122   A#  Major             88
# 377   909001996                  74  ...  100    F  Minor             80
# 422  1260594497                 120  ...  180   C#  Major             64
# 676   685071800                  21  ...   92  NaN  Major             86
# 716   312622938                  13  ...   94   C#  Minor             76
# 766   461558540                  27  ...   78    F  Major             56
# 767   417230415                   7  ...   93  NaN  Minor             79
# 770   313113297                   7  ...  142  NaN  Major             87
# 773   305650299                   9  ...   85   A#  Major             71
# 778   338422004                  10  ...  130   C#  Major             82
# 781   403231558                   5  ...  152    B  Major             84
# 784   283359161                   4  ...  121   F#  Minor             86
# 786   283332261                   8  ...  188    F  Minor             50
# 788   279737940                   7  ...  105   G#  Major             81
# 789   212351890                   9  ...  118   G#  Major             63
# 792   246127838                   6  ...  115   C#  Minor             85
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 4           23       80             14                  63          11
# 192         19       72             10                   0          13
# 239         23       48             14                   0           6
# 362         43       50              7                   0          14
# 377         29       67             29                   0          12
# 422         44       65             28                   0          14
# 676         89       79             17                   0          11
# 716         81       80             20                   0          25
# 766         61       90             36                   0          18
# 767         22       55             31                   0          12
# 770         93       59             28                   0          17
# 773         43       65             23                   0           9
# 778         50       67             12                   0          13
# 781         74       69             21                   0          18
# 784         67       65             42                   0          35
# 786         41       50             69                   0          12
# 788         77       79             19                   0          47
# 789         60       70              5                   0           9
# 792         72       58              9                   0          49
#
#      speechiness_%
# 4                6
# 192             25
# 239              5
# 362              5
# 377              3
# 422             12
# 676              6
# 716              4
# 766             31
# 767              5
# 770              5
# 773              5
# 778              5
# 781              6
# 784              7
# 786              6
# 788              8
# 789             31
# 792             12
#
# [19 rows x 24 columns]

# %%
drake_songs = sample_dataset[sample_dataset.iloc[:,1] == 'Drake']

# %%
drake_songs
# Out:
#           track_name artist(s)_name  artist_count  released_year  \
# 235  Search & Rescue          Drake             1           2023
# 865          Massive          Drake             1           2022
# 874           Sticky          Drake             1           2022
# 945  BackOutsideBoyz          Drake             1           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 235               4             7                  2066                  6
# 865               6            17                  5263                  0
# 874               6            17                  2814                  0
# 945              11             4                  1045                  0
#
#        streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 235  175097833                  58  ...  142  A#  Minor             82
# 865  195628667                  66  ...  125   E  Minor             51
# 874  191448892                  38  ...  137  A#  Minor             88
# 945   93367537                   8  ...  142   F  Minor             85
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 235         54       44              6                   0          33
# 865          5       68             12                   2          15
# 874          8       49              9                   0           9
# 945         40       43              4                   0          39
#
#      speechiness_%
# 235              7
# 865              6
# 874             14
# 945             32
#
# [4 rows x 24 columns]

# %%
plt.bar(drake_songs['track_name'],
         drake_songs['streams'], 
         color  = ['red', 'green'])
plt.bar(bad_bunny_songs['track_name'][0:5],
         bad_bunny_songs['streams'][0:5], 
         color  = ['orange', 'navy'])
# Out:
# <BarContainer object of 5 artists>
